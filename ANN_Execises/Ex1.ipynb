# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhnt19146391/thanhnt19146391/blob/main/Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_gray_img(img):
    plt.imshow(img, cmap = plt.get_cmap('gray'))
    plt.colorbar()
    plt.show()

# %%
def show_rgb_img(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.colorbar()
    plt.show()

# %%
IMG_SIZE = (150 , 150)
path = "/content/drive/MyDrive/Colab Notebooks/AI/ANN_Execises/Images/"

# %%
# Generate datasets
for i in range(12):    
    img = cv2.imread(path + str(i) + ".jpg")
    min = np.min(img.shape[:2])    
    img = img[:min, :min]
    img = cv2.resize(img, IMG_SIZE)
    # img = img.astype("float32")
    # img /= 255
    
show_gray_img(img)
